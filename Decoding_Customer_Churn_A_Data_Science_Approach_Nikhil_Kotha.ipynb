# %% [markdown]
# ### INFO 7390 Art_and_Science_of_Data
# # **Decoding Customer Churn: A Data Science Approach**
#
# **Nikhil Kotha - 002651481**

# %% [markdown]
# ![1_47xx1oXuebvYwZeB0OutuA.png](data:image/png;base64,...)

# %% [markdown]
# # **What Is the Core Research Focus?**
#
# This study focuses on predicting customer churn in the banking sector using data science techniques. The goal is to develop a model that can identify customers at risk of leaving the bank and help financial institutions implement proactive retention strategies.
#
# # **Key Objectives:**
#
# **Understanding Factors Influencing Customer Churn:**
#
# *   Analyzing key attributes such as credit score, account balance, tenure, and product usage to determine which factors contribute to customer attrition.
# *   Visualizing trends to gain insights into why customers close their accounts or switch banks.
#
# **Developing a Predictive Churn Model:**
#
# *   Classifying customers into high-risk (likely to churn) and low-risk (likely to stay) categories.
# *   Assigning a churn probability score, allowing banks to target at-risk customers with personalized retention efforts.
#
# # **Methodology:**
#
# The research involves preprocessing and engineering financial and demographic data, selecting suitable machine learning models, and evaluating their performance. The insights generated from the model will help banks optimize customer engagement strategies, personalize services, and minimize churn-related revenue losses.

# %% [markdown]
# ### **Why Customer Churn Prediction Matters**
# **The Value of Understanding Churn**
#
# Customer churn prediction is a key area in data analytics that helps businesses maintain their customer base, optimize resources, and drive revenue growth. By leveraging data-driven insights, companies can anticipate customer behavior and take proactive steps to reduce churn. Here’s why this field is crucial:
#
# # **1. Reducing Acquisition Costs**
#
# ![Probability-of-Selling-to-New-vs-Existing-Customer.png](data:image/png;base64,...)
#
# Acquiring a new customer is often far more expensive than keeping an existing one. By identifying customers who are likely to leave, businesses can implement targeted retention strategies, minimizing the need for expensive acquisition campaigns.

# %% [markdown]
# # **2. Sustaining Revenue Growth**
#
#
# ![image-18.png](data:image/png;base64,...)
#
#
# Customer churn directly affects revenue streams. Predicting and preventing it ensures steady cash flow, which is particularly important for businesses that depend on long-term customer relationships.

# %% [markdown]
# # **3. Enhancing Customer Experience**
#
# ![infographics-loop-square-1-768x756-1.png](data:image/png;base64,...)
#
# Analyzing churn helps businesses pinpoint reasons why customers leave, whether it's poor service, high prices, or product dissatisfaction. By addressing these issues, companies can enhance customer satisfaction and loyalty.

# %% [markdown]
# # **4. Optimizing Resource Allocation**
#
# ![2870706-rId19.jpeg](data:image/jpeg;base64,...)
#
# Instead of using one-size-fits-all retention strategies, businesses can prioritize high-risk customers for interventions. This efficient allocation of resources maximizes retention efforts and reduces wasted expenditures.

# %% [markdown]
# # **5. Staying Ahead of the Competition**
#
# ![Screen-Shot-2022-08-11-at-3.35.49-PM (1).jpg](data:image/jpeg;base64,...)
#
# Companies that effectively reduce churn maintain a stronger market position. A solid customer retention strategy builds brand trust and loyalty, making it harder for competitors to lure customers away.

# %% [markdown]
# ## **6. Leveraging Data for Smarter Decisions**
#
# ![5-telco-customer-churn.png](data:image/png;base64,...)
#
# Churn prediction relies on analyzing vast amounts of customer data to uncover trends. This data-driven approach enables companies to make strategic decisions based on real insights rather than assumptions.

# %% [markdown]
# # **7. Essential for Subscription-Based Businesses**
#
# ![66ea839f8eb9400c2d4a499d_66e9fd5a0fca221ec56c8a5a_66e9fc901a96e84530147fbe_62520cx2520financial2520(1).png](data:image/png;base64,...)
#
# Industries like telecommunications, SaaS, and streaming services thrive on long-term customer engagement. Predicting churn ensures businesses retain subscribers and maintain recurring revenue streams.

# %% [markdown]
# # **8. Increasing Customer Lifetime Value (CLV)**
#
# ![Formula-for-calculating-lifetime-value-of-a-customer.webp](data:image/webp;base64,...)
#
# A longer customer relationship translates to higher profitability. By minimizing churn, companies can maximize the total value derived from each customer, boosting long-term earnings.

# %% [markdown]
# # **9. Harnessing the Power of Predictive Analytics**
#
# ![https-lh3-googleusercontent-com-purwbwzko1ru9ji2.png](data:image/png;base64,...)
#
# Churn prediction is a real-world application of predictive analytics. Using machine learning models, businesses can forecast future customer behavior and take proactive measures before churn occurs.

# %% [markdown]
# # **10. Continuous Model Improvement**
#
# ![cx-Feedback-1024x563.png](data:image/png;base64,...)
#
# Churn prediction models are not static—they evolve with changing customer behaviors and market conditions. Regular updates ensure businesses stay ahead of trends and maintain high retention rates.

# %% [markdown]
# # **Final Thoughts**
# Churn prediction is more than just a business strategy—it’s an ongoing process that combines data science, customer behavior analysis, and strategic planning. By leveraging advanced analytics and machine learning, companies can prevent revenue loss, improve customer satisfaction, and stay competitive in a dynamic market.

# %% [markdown]
# **## Theoretical Basis of Churn Prediction**
#
# Churn prediction relies on analyzing customer behavior and applying machine learning to identify patterns that indicate the likelihood of account closure. Factors such as credit score, account balance, tenure, and product usage help classify customers as high or low risk for churn.
#
# Machine learning models like logistic regression, decision trees, and random forests analyze historical banking data to detect churn-related trends. These models assign a probability score to each customer, allowing banks to implement targeted retention strategies.
#
# Since customer behavior evolves, churn models require continuous updates. Regular retraining with new data ensures accurate predictions, helping financial institutions improve customer retention, optimize engagement, and reduce revenue loss.

# %% [markdown]
# # **Step 1: Theoretical Foundations**
#
# **Understanding Algorithms and Problem Design**
#
# In data science, algorithms are structured computational methods used for data processing, prediction, and decision-making. They follow a sequence of steps to transform input data into meaningful outcomes. The effectiveness of an algorithm depends on its efficiency, scalability, and accuracy, which directly influence the performance of data-driven solutions.
#
# Problem design focuses on defining the problem clearly, ensuring a strong understanding of the data, objectives, and constraints involved. A well-structured problem statement helps in selecting the most suitable algorithm and ensures that the solution effectively addresses the core issue. A deep understanding of both the business domain and data structure is essential to achieve meaningful results.
#
# **Importance of Custom Problem Creation in Learning**
#
# Creating custom problem sets is an essential teaching strategy in data science. Tailored problems align with course objectives, ensuring students engage with material at the right level of complexity while applying concepts to real-world scenarios. This approach strengthens critical thinking, problem-solving, and practical application of theoretical knowledge.
#
# By integrating real datasets and industry-relevant challenges, educators can create more engaging and practical learning experiences. This is particularly valuable in data science, where tools, techniques, and business needs evolve rapidly. Custom problem creation also enables better assessment of students’ analytical and creative skills.
#
# **Enhancing Learning with AI Tools like ChatGPT**
#
# AI-powered tools like ChatGPT can improve both teaching and learning experiences in data science. Educators can use ChatGPT to generate problem sets, explain complex topics, and create datasets for analysis. Students benefit from instant feedback, guidance on problem-solving approaches, and deeper conceptual understanding through interactive engagement.
#
# Additionally, ChatGPT can simulate real-world data science scenarios, encouraging students to apply their skills in novel and dynamic ways. By leveraging AI, educators can create a more interactive, adaptive, and personalized learning environment, better preparing students for the evolving challenges of the data science industry.

# %% [markdown]
# # **Step 2: Introduction to the Practical Example**
#
# The practical example in this context involves developing a churn prediction model for a banking institution. The objective is to identify customers at risk of closing their accounts so that proactive retention strategies can be implemented. Churn prediction is crucial in banking as customer departures directly impact revenue, operational stability, and long-term financial growth. By accurately forecasting churn, banks can optimize resource allocation, improve customer engagement, and enhance service offerings to retain valuable clients.
#
# **Relevance and Impact in Data Science**
#
# Churn prediction is a real-world application of data science that helps businesses make data-driven decisions. It relies on analyzing customer demographics, transaction patterns, product usage, and account tenure to uncover behavioral trends. The ability to accurately predict churn is essential for reducing attrition, improving customer loyalty, and driving long-term profitability. Additionally, it highlights the power of data science in shaping customer retention strategies and personalized banking solutions.
#
# **Core Data Science Principles in the Example**
#
# This churn prediction model applies several fundamental concepts in data science:
#
# **1.Data Preparation and Feature Engineering**
#
#
# *   Cleaning raw data, handling missing values, and extracting meaningful features to improve model accuracy.
#
# *   Ensuring the dataset is structured and optimized for predictive analysis.
#
# **2.Model Selection and Performance Evaluation**
#
#
#
# *   Choosing appropriate machine learning algorithms (e.g., decision trees, random forests, or gradient boosting).
#
#
# *   Evaluating performance using accuracy, precision, recall, and F1-score to determine the model’s effectiveness.
#
# **3.Predictive Analytics for Risk Assessment**
#
#
#
# *   Using machine learning techniques to analyze historical transaction and account data.
#
# *   Forecasting which customers are likely to close their accounts, allowing banks to take preventative action.
#
# **4.Turning Insights into Business Strategies**
#
#
#
# *   The ultimate goal is to translate predictions into actionable retention strategies.
#
# *   Implementing personalized offers, loyalty programs, or targeted outreach to prevent churn.

# %% [markdown]
# # **Step 3: Examining the Practical Example**
#
# **Challenges and Constraints**
#
# Developing a churn prediction model for a banking institution presents several challenges:
#
#
#
# 1.   **Data Accuracy and Availability –** The model's performance depends on high-quality financial and customer data. Missing values, incorrect entries, or limited transaction history can reduce predictive accuracy.
# 2.   **Selecting Relevant Features –** Identifying the most influential factors behind customer churn requires domain expertise. Some critical financial behaviors may not be captured in available datasets.
# 1.   **Balancing Complexity and Interpretability –** More advanced machine learning models may yield better predictions but can be difficult to interpret, making it harder for stakeholders to act on insights.
#
# 1.   **Adapting to Evolving Customer Behavior –** Banking customers’ financial habits and product usage change over time, meaning models must be continuously updated to stay relevant.
# 2.   **Ethical Considerations and Data Privacy –** Handling customer financial data must comply with privacy regulations, ensuring sensitive information is protected and bias is minimized.
#
# **Logical Approach to Churn Prediction**
#
# To build an effective model, the following steps are undertaken:
#
#
#
# 1.   **Data Preparation – **Cleaning and processing customer data to remove inconsistencies and handle missing values.
# 1.   **Feature Engineering –** Creating new variables, such as customer engagement scores or transaction frequency, to improve predictive performance.
# 1.   **Choosing the Right Model –** Selecting a suitable classification algorithm based on the dataset, considering accuracy and interpretability.
# 2.   **Training and Evaluating Performance –** Using train-test splits and measuring performance with metrics like precision, recall, and F1-score to ensure reliability.
# 2.   **Deployment and Continuous Monitoring –** Implementing the model to make real-time predictions and updating it based on new customer data.
#
#
# **Core Algorithmic Concepts Applied**
#
# 1.   **Supervised Learning -**A classification problem where the model predicts whether a customer will churn based on historical data.
# 1.   **Decision Trees & Ensemble Models –** Techniques such as random forests and gradient boosting are commonly used due to their high predictive accuracy.
# 1.   **Performance Metrics –** Since churn data is often imbalanced, precision and recall are more critical than overall accuracy.
# 2.   **Cross-Validation –** Ensuring the model generalizes well by testing it on multiple subsets of the dataset.
# 2.   **Feature Importance Analysis –** Identifying which factors (e.g., account balance, tenure, or transaction activity) contribute most to churn risk.

# %% [markdown]
# # **Step 4: Enhancing Understanding Through AI Interaction**
#
# Utilizing ChatGPT or similar AI tools can significantly deepen comprehension of complex topics like churn prediction. These tools provide an interactive way to explore data science concepts, refine problem-solving approaches, and validate ideas through dynamic discussions.
#
# **Understanding the Core Aspects of Churn Prediction**
#
# A key aspect of leveraging AI is exploring the intricacies of the problem. Asking about the most relevant data points for predicting churn across different industries can offer valuable insights into feature selection and the role of domain knowledge in modeling. Discussing the suitability of various machine learning algorithms, such as logistic regression, decision trees, and neural networks, allows for a better understanding of which models align best with the dataset and problem constraints. Additionally, engaging in conversations about model evaluation metrics can clarify why measures like the F1-score or AUC-ROC are often more relevant than simple accuracy when assessing churn predictions.
#
# **Generating Ideas for Problem-Specific Challenges**
#
# Beyond understanding the fundamentals, AI tools help generate ideas for addressing specific challenges in churn prediction. One common issue is data imbalance, where the number of churned customers is significantly lower than retained customers. Exploring techniques such as SMOTE (Synthetic Minority Over-sampling Technique), undersampling, or adjusting class weights can improve prediction fairness and accuracy.
#
# Since customer behavior is constantly evolving, discussing methods to incorporate dynamic trends into models—such as time-series analysis or recurrent neural networks (RNNs)—can enhance prediction reliability. AI can also help brainstorm privacy preservation techniques, including data anonymization or differential privacy, to ensure compliance with industry standards and regulatory requirements.
#
# **Validating Strategies and Cross-Checking Insights**
#
# AI-driven discussions can also be used to cross-check and validate strategies before implementation. Exploring existing literature and case studies can provide empirical evidence to support or challenge a proposed approach. Seeking AI-simulated expert opinions can introduce industry best practices or emerging trends that might refine a predictive model. Additionally, assessing the technical feasibility of a solution, including potential implementation challenges, can help fine-tune an approach to ensure it is practical and effective.
#
# **Using AI as a Learning and Development Tool**
#
# By iteratively engaging in queries, idea generation, and validation through AI, it is possible to refine churn prediction strategies and develop a more comprehensive understanding of the problem. Rather than relying on AI to provide direct solutions, the goal is to use it as a tool to enhance critical thinking, problem-solving skills, and the ability to translate data insights into actionable business strategies.

# %% [markdown]
# ## Step 5. Crafting Your New Problem
#
# ### Problem Statement
#
#
# Develop a churn prediction model for a financial institution offering various banking products. The model should predict the likelihood of a customer discontinuing their banking relationship within the next six months. This prediction will enable the institution to implement targeted retention strategies.
#
#
# ### Input and Output Format
#
# **Input Format**: A CSV file containing customer data with the following columns:
#
# - CustomerID (unique identifier for each customer)
#
# - Age (customer's age)
#
# - Tenure (number of years the customer has been with the bank)
#
# - Balance (current balance in the customer's account)
#
# - NumOfProducts (number of banking products the customer is using)
#
# - HasCrCard (1 if the customer has a credit card, 0 otherwise)
#
# - IsActiveMember (1 if the customer is considered active, 0 otherwise)
#
# - EstimatedSalary (customer's estimated salary)
#
# - Geography (customer's country)
#
# - Gender (customer's gender)
#
# **Output Format**: A CSV file with two columns:
#
# - CustomerID
#
# - ChurnProbability (a probability score between 0 and 1 indicating the likelihood of churn)
#
# **Sample Input**:
# CustomerID,Age,Tenure,Balance,NumOfProducts,HasCrCard,IsActiveMember,EstimatedSalary,Geography,Gender
# 15634602,42,2,0.00,1,1,1,101348.88,France,Female
#
#
# **Sample Output**:
# CustomerID,ChurnProbability
# 15634602,0.65
#
# ### Constraints
#
# 1. **Data Quality and Completeness**: The model must handle missing values intelligently, either by imputation or exclusion, without significantly impacting the prediction accuracy.
#
# 2. **Feature Engineering**: You are required to create at least two new features that could potentially improve the model's performance based on the given data.
#
# 3. **Model Interpretability**: While striving for high accuracy, the model should also be interpretable. You should be able to explain the impact of at least the top three features influencing the churn prediction.
#
# 4. **Imbalanced Dataset Handling**: If the dataset is imbalanced (i.e., the number of churned customers is significantly lower than the number of retained customers), appropriate techniques must be applied to address this imbalance.
#
# 5. **Model Evaluation**: The model must be evaluated using at least three metrics (e.g., accuracy, precision, recall, F1-score) to ensure its performance is robust across different aspects of churn prediction.
#
# 6. **Privacy and Ethics**: Any personal information must be anonymized, and the model should not discriminate based on sensitive attributes such as gender, race, or ethnicity.
#
# By addressing these constraints and following the specified input and output formats, the churn prediction model can be developed to meet the financial institution's needs, providing actionable insights to reduce customer attrition effectively.

# %% [markdown]
# ## Review and Preparation of the Dataset
#
# This section focuses on analyzing the structure of the dataset to gain insights into its composition. The primary objectives are:
# 1. To examine the dataset's input space and understand the nature of the available features.
# 2. To prepare the data for exploratory analysis and predictive modeling, following the methodology outlined in Section 1.

# %%
## REQUIRED LIBRARIES
# For data wrangling
import numpy as np
import pandas as pd

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
# Read the data frame
url = "https://raw.githubusercontent.com/Kotha-Nikhil/INFO-7390-/refs/heads/main/Churn_Modelling.csv"
df = pd.read_csv(url)
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# The Df has 1000 rows with 14 attributes. We review this further to identify what attributes will be necessary and what data manipulation needs to be carried out before Exploratory analysis and prediction modelling

# %%
# Check columns list and missing values
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# Well isn't that a rare find; no missing values!

# %%
# Get unique count for each variable
df.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %% [markdown]
# From the above, we will not require the first 2 attributes as the are specific to a customer. It is borderline with the surname as this would result to profiling so we exclude this as well.

# %%
# Drop the columns as explained above
df = df.drop(["RowNumber", "CustomerId", "Surname"], axis = 1)

# %%
# Review the top rows of what is left of the data frame
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# **Key Questions and Considerations**
#
# Several important questions arise from the dataset analysis:
#
# 1. The dataset appears to be a snapshot at a single point in time, particularly regarding the account balance. This raises questions such as the specific date of the snapshot and its relevance. A more informative approach might involve tracking balances over a period of time rather than relying on a single static value.
# 2. Some customers are marked as exited but still have an account balance. This ambiguity leads to speculation—does this mean they have left a specific banking product rather than the institution as a whole? Understanding whether churn applies to individual services or complete bank exits would help refine the analysis.
# 3. The definition of an active member is unclear. Are there varying degrees of activity, and would a more granular measure, such as transaction count (both debits and credits), provide a better indicator of engagement?
# 4. Simply listing the number of banking products a customer has may not be sufficient. A breakdown of the specific products they use could provide more meaningful insights into customer behavior and retention patterns.
#
# For this exercise, the model will be developed without additional contextual information. However, in a real-world scenario, a deeper understanding of the data extraction process and business context would likely enhance the predictive model’s effectiveness, leading to more reliable and interpretable insights.

# %%
# Check variable data types
df.dtypes
# Out:
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# So we moslty have categorical variables and 5 continuous variables

# %% [markdown]
# ##  Exploratory Data Analysis (EDA)
# The primary objective in this section is to analyze how the given attributes correlate with a customer's churn (Exit) status. By examining these relationships, we aim to uncover patterns and trends that could provide insights into the factors influencing customer attrition.

# %%
labels = 'Exited', 'Retained'
sizes = [df.Exited[df['Exited']==1].count(), df.Exited[df['Exited']==0].count()]
explode = (0, 0.1)
fig1, ax1 = plt.subplots(figsize=(10, 8))
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.title("Proportion of customer churned and retained", size = 20)
plt.show()

# %% [markdown]
# **From above piechart we notice:**
#
# **So about 20% of the customers have churned. So the baseline model could be to predict that 20% of the customers will churn.
# Given 20% is a small number,  we need to ensure that the chosen model does predict with great accuracy this 20% as it is of interest to the bank to identify and keep this bunch as opposed to accurately predicting the customers that are retained.**

# %%
    # We first review the 'Status' relation with categorical variables
    fig, axarr = plt.subplots(2, 2, figsize=(20, 12))
    sns.countplot(x='Geography', hue = 'Exited',data = df, ax=axarr[0][0])
    sns.countplot(x='Gender', hue = 'Exited',data = df, ax=axarr[0][1])
    sns.countplot(x='HasCrCard', hue = 'Exited',data = df, ax=axarr[1][0])
    sns.countplot(x='IsActiveMember', hue = 'Exited',data = df, ax=axarr[1][1])
# Out:
# <Axes: xlabel='IsActiveMember', ylabel='count'>

# %% [markdown]
# **From above we note the following:**
# * Majority of the data is from persons from France. However, the proportion of churned customers is with inversely related to the population of customers alluding to the bank possibly having a problem (maybe not enough customer service resources allocated) in the areas where it has fewer clients.
# * The proportion of female customers churning is also greater than that of male customers
# * Interestingly, majority of the customers that churned are those with credit cards. Given that majority of the customers have credit cards could prove this to be just a coincidence.
# * Unsurprisingly the inactive members have a greater churn. Worryingly is that the overall proportion of inactive mebers is quite high suggesting that the bank may need a program implemented to turn this group to active customers as this will definately have a positive impact on the customer churn.

# %%
    # Relations based on the continuous data attributes
    fig, axarr = plt.subplots(3, 2, figsize=(20, 12))
    sns.boxplot(y='CreditScore',x = 'Exited', hue = 'Exited',data = df, ax=axarr[0][0])
    sns.boxplot(y='Age',x = 'Exited', hue = 'Exited',data = df , ax=axarr[0][1])
    sns.boxplot(y='Tenure',x = 'Exited', hue = 'Exited',data = df, ax=axarr[1][0])
    sns.boxplot(y='Balance',x = 'Exited', hue = 'Exited',data = df, ax=axarr[1][1])
    sns.boxplot(y='NumOfProducts',x = 'Exited', hue = 'Exited',data = df, ax=axarr[2][0])
    sns.boxplot(y='EstimatedSalary',x = 'Exited', hue = 'Exited',data = df, ax=axarr[2][1])
# Out:
# <Axes: xlabel='Exited', ylabel='EstimatedSalary'>

# %% [markdown]
# **We note the following:**
# * There is no significant difference in the credit score distribution between retained and churned customers.
# * The older customers are churning at more than the younger ones alluding to a difference in service preference in the age categories. The bank may need to review their target market or review the strategy for retention between the different age groups
# * With regard to the tenure, the clients on either extreme end (spent little time with the bank or a lot of time with the bank) are more likely to churn compared to those that are of average tenure.
# *  Worryingly, the bank is losing customers with significant bank balances which is likely to hit their available capital for lending.
# * Neither the product nor the salary has a significant effect on the likelihood to churn.

# %% [markdown]
# ##  Feature engineering
# We seek to add features that are likely to have an impact on the probability of churning. We first split the train and test sets

# %%
# Split Train, test data
df_train = df.sample(frac=0.8,random_state=200)
df_test = df.drop(df_train.index)
print(len(df_train))
print(len(df_test))
# Out:
# 8000
# 2000

# %%
df_train['BalanceSalaryRatio'] = df_train.Balance/df_train.EstimatedSalary
sns.boxplot(y='BalanceSalaryRatio',x = 'Exited', hue = 'Exited',data = df_train)
plt.ylim(-1, 5)
# Out:
# (-1.0, 5.0)

# %% [markdown]
# **From above we note the following:**
#
# we have seen that the salary has little effect on the chance of a customer churning. However as seen above, the ratio of the bank balance and the estimated salary indicates that customers with a higher balance salary ratio churn more which would be worrying to the bank as this impacts their source of loan capital.

# %%
# Given that tenure is a 'function' of age, we introduce a variable aiming to standardize tenure over age:
df_train['TenureByAge'] = df_train.Tenure/(df_train.Age)
sns.boxplot(y='TenureByAge',x = 'Exited', hue = 'Exited',data = df_train)
plt.ylim(-1, 1)
plt.show()

# %%
'''Lastly we introduce a variable to capture credit score given age to take into account credit behaviour visavis adult life
:-)'''
df_train['CreditScoreGivenAge'] = df_train.CreditScore/(df_train.Age)

# %%
# Resulting Data Frame
df_train.head()
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 8159          461     Spain  Female   25       6       0.00              2
# 6332          619    France  Female   35       4   90413.12              1
# 8895          699    France  Female   40       8  122038.34              1
# 5351          558   Germany    Male   41       2  124227.14              1
# 4314          638    France    Male   34       5  133501.36              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  BalanceSalaryRatio  \
# 8159          1               1         15306.29       0            0.000000
# 6332          1               1         20555.21       0            4.398550
# 8895          1               0        102085.35       0            1.195454
# 5351          1               1        111184.67       0            1.117305
# 4314          0               1        155643.04       0            0.857741
#
#       TenureByAge  CreditScoreGivenAge
# ...

# %% [markdown]
# ##  Data prep for model fitting

# %%
# Arrange columns by data type for easier manipulation
continuous_vars = ['CreditScore',  'Age', 'Tenure', 'Balance','NumOfProducts', 'EstimatedSalary', 'BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
cat_vars = ['HasCrCard', 'IsActiveMember','Geography', 'Gender']
df_train = df_train[['Exited'] + continuous_vars + cat_vars]
df_train.head()
# Out:
#       Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 8159       0          461   25       6       0.00              2
# 6332       0          619   35       4   90413.12              1
# 8895       0          699   40       8  122038.34              1
# 5351       0          558   41       2  124227.14              1
# 4314       0          638   34       5  133501.36              1
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         15306.29            0.000000     0.240000            18.440000
# 6332         20555.21            4.398550     0.114286            17.685714
# 8895        102085.35            1.195454     0.200000            17.475000
# 5351        111184.67            1.117305     0.048780            13.609756
# 4314        155643.04            0.857741     0.147059            18.764706
#
#       HasCrCard  IsActiveMember Geography  Gender
# 8159          1               1     Spain  Female
# ...

# %%
'''For the one hot variables, we change 0 to -1 so that the models can capture a negative relation
where the attribute in inapplicable instead of 0'''
df_train.loc[df_train.HasCrCard == 0, 'HasCrCard'] = -1
df_train.loc[df_train.IsActiveMember == 0, 'IsActiveMember'] = -1
df_train.head()
# Out:
#       Exited  CreditScore  Age  Tenure    Balance  NumOfProducts  \
# 8159       0          461   25       6       0.00              2
# 6332       0          619   35       4   90413.12              1
# 8895       0          699   40       8  122038.34              1
# 5351       0          558   41       2  124227.14              1
# 4314       0          638   34       5  133501.36              1
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         15306.29            0.000000     0.240000            18.440000
# 6332         20555.21            4.398550     0.114286            17.685714
# 8895        102085.35            1.195454     0.200000            17.475000
# 5351        111184.67            1.117305     0.048780            13.609756
# 4314        155643.04            0.857741     0.147059            18.764706
#
#       HasCrCard  IsActiveMember Geography  Gender
# 8159          1               1     Spain  Female
# ...

# %%
# One hot encode the categorical variables
lst = ['Geography', 'Gender']
remove = list()
for i in lst:
    if (df_train[i].dtype == np.str_ or df_train[i].dtype == np.object_):
        for j in df_train[i].unique():
            df_train[i+'_'+j] = np.where(df_train[i] == j,1,-1)
        remove.append(i)
df_train = df_train.drop(remove, axis=1)
df_train.head()
# Out:
# <ipython-input-26-9fc8eec02841>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[i+'_'+j] = np.where(df_train[i] == j,1,-1)
# <ipython-input-26-9fc8eec02841>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train[i+'_'+j] = np.where(df_train[i] == j,1,-1)
# <ipython-input-26-9fc8eec02841>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# minMax scaling the continuous variables
minVec = df_train[continuous_vars].min().copy()
maxVec = df_train[continuous_vars].max().copy()
df_train[continuous_vars] = (df_train[continuous_vars]-minVec)/(maxVec-minVec)
df_train.head()
# Out:
#       Exited  CreditScore       Age  Tenure   Balance  NumOfProducts  \
# 8159       0        0.222  0.094595     0.6  0.000000       0.333333
# 6332       0        0.538  0.229730     0.4  0.360358       0.000000
# 8895       0        0.698  0.297297     0.8  0.486406       0.000000
# 5351       0        0.416  0.310811     0.2  0.495130       0.000000
# 4314       0        0.576  0.216216     0.5  0.532094       0.000000
#
#       EstimatedSalary  BalanceSalaryRatio  TenureByAge  CreditScoreGivenAge  \
# 8159         0.076118            0.000000     0.432000             0.323157
# 6332         0.102376            0.003317     0.205714             0.305211
# 8895         0.510225            0.000901     0.360000             0.300198
# 5351         0.555744            0.000843     0.087805             0.208238
# 4314         0.778145            0.000647     0.264706             0.330882
#
#       HasCrCard  IsActiveMember  Geography_Spain  Geography_France  \
# ...

# %%
# data prep pipeline for test data
def DfPrepPipeline(df_predict,df_train_Cols,minVec,maxVec):
    # Add new features
    df_predict['BalanceSalaryRatio'] = df_predict.Balance/df_predict.EstimatedSalary
    df_predict['TenureByAge'] = df_predict.Tenure/(df_predict.Age - 18)
    df_predict['CreditScoreGivenAge'] = df_predict.CreditScore/(df_predict.Age - 18)
    # Reorder the columns
    continuous_vars = ['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary','BalanceSalaryRatio',
                   'TenureByAge','CreditScoreGivenAge']
    cat_vars = ['HasCrCard','IsActiveMember',"Geography", "Gender"]
    df_predict = df_predict[['Exited'] + continuous_vars + cat_vars]
    # Change the 0 in categorical variables to -1
    df_predict.loc[df_predict.HasCrCard == 0, 'HasCrCard'] = -1
    df_predict.loc[df_predict.IsActiveMember == 0, 'IsActiveMember'] = -1
    # One hot encode the categorical variables
    lst = ["Geography", "Gender"]
    remove = list()
    for i in lst:
        for j in df_predict[i].unique():
            df_predict[i+'_'+j] = np.where(df_predict[i] == j,1,-1)
        remove.append(i)
    df_predict = df_predict.drop(remove, axis=1)
    # Ensure that all one hot encoded variables that appear in the train data appear in the subsequent data
    L = list(set(df_train_Cols) - set(df_predict.columns))
    for l in L:
        df_predict[str(l)] = -1
    # MinMax scaling coontinuous variables based on min and max from the train data
    df_predict[continuous_vars] = (df_predict[continuous_vars]-minVec)/(maxVec-minVec)
    # Ensure that The variables are ordered in the same way as was ordered in the train set
    df_predict = df_predict[df_train_Cols]
    return df_predict

# %% [markdown]
# ## Model fitting and selection
# For the model fitting, I will try out the following
# * Logistic regression in the primal space and with different kernels
# * SVM in the primal and with different Kernels
# * Ensemble models

# %%
# Support functions
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from scipy.stats import uniform

# Fit models
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Scoring functions
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
# Function to give best model score and parameters
def best_model(model):
    print(model.best_score_)
    print(model.best_params_)
    print(model.best_estimator_)
def get_auc_scores(y_actual, method,method2):
    auc_score = roc_auc_score(y_actual, method);
    fpr_df, tpr_df, _ = roc_curve(y_actual, method2);
    return (auc_score, fpr_df, tpr_df)

# %%
# Fit primal logistic regression
param_grid = {'C': [0.1,0.5,1,10,50,100], 'max_iter': [250], 'fit_intercept':[True],'intercept_scaling':[1],
              'penalty':['l2'], 'tol':[0.00001,0.0001,0.000001]}
log_primal_Grid = GridSearchCV(LogisticRegression(solver='lbfgs'),param_grid, cv=10, refit=True, verbose=0)
log_primal_Grid.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
best_model(log_primal_Grid)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Fit logistic regression with degree 2 polynomial kernel
param_grid = {'C': [0.1,10,50], 'max_iter': [300,500], 'fit_intercept':[True],'intercept_scaling':[1],'penalty':['l2'],
              'tol':[0.0001,0.000001]}
poly2 = PolynomialFeatures(degree=2)
df_train_pol2 = poly2.fit_transform(df_train.loc[:, df_train.columns != 'Exited'])
log_pol2_Grid = GridSearchCV(LogisticRegression(solver = 'liblinear'),param_grid, cv=5, refit=True, verbose=0)
log_pol2_Grid.fit(df_train_pol2,df_train.Exited)
best_model(log_pol2_Grid)
# Out:
# 0.8553750000000001
# {'C': 50, 'fit_intercept': True, 'intercept_scaling': 1, 'max_iter': 300, 'penalty': 'l2', 'tol': 1e-06}
# LogisticRegression(C=50, max_iter=300, solver='liblinear', tol=1e-06)

# %%
# Fit SVM with RBF Kernel
param_grid = {'C': [0.5,100,150], 'gamma': [0.1,0.01,0.001],'probability':[True],'kernel': ['rbf']}
SVM_grid = GridSearchCV(SVC(), param_grid, cv=3, refit=True, verbose=0)
SVM_grid.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
best_model(SVM_grid)
# Out:
# 0.8518747609662071
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf', 'probability': True}
# SVC(C=100, gamma=0.1, probability=True)

# %%
# Fit SVM with pol kernel
param_grid = {'C': [0.5,1,10,50,100], 'gamma': [0.1,0.01,0.001],'probability':[True],'kernel': ['poly'],'degree':[2,3] }
SVM_grid = GridSearchCV(SVC(), param_grid, cv=3, refit=True, verbose=0)
SVM_grid.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
best_model(SVM_grid)
# Out:
# 0.8544999485716948
# {'C': 100, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly', 'probability': True}
# SVC(C=100, degree=2, gamma=0.1, kernel='poly', probability=True)

# %%
# Fit random forest classifier
param_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators':[50,100],'min_samples_split': [3, 5, 6, 7]}
RanFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, refit=True, verbose=0)
RanFor_grid.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
best_model(RanFor_grid)
# Out:
# 0.8631250000000001
# {'max_depth': 8, 'max_features': 6, 'min_samples_split': 7, 'n_estimators': 50}
# RandomForestClassifier(max_depth=8, max_features=6, min_samples_split=7,
#                        n_estimators=50)

# %%
# Fit Extreme Gradient boosting classifier
param_grid = {'max_depth': [5,6,7,8], 'gamma': [0.01,0.001,0.001],'min_child_weight':[1,5,10], 'learning_rate': [0.05,0.1, 0.2, 0.3], 'n_estimators':[5,10,20,100]}
xgb_grid = GridSearchCV(XGBClassifier(), param_grid, cv=5, refit=True, verbose=0)
xgb_grid.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
best_model(xgb_grid)

# %% [markdown]
# ### Fit best Models

# %%
# Fit primal logistic regression
log_primal = LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,intercept_scaling=1, max_iter=250, multi_class='multinomial',n_jobs=None,
                                penalty='l2', random_state=None, solver='lbfgs',tol=1e-05, verbose=0, warm_start=False)
log_primal.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1237: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, binary problems will be fit as proper binary  logistic regression models (as if multi_class='ovr' were set). Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(C=100, max_iter=250, multi_class='multinomial', tol=1e-05)

# %%
# Fit logistic regression with pol 2 kernel
poly2 = PolynomialFeatures(degree=2)
df_train_pol2 = poly2.fit_transform(df_train.loc[:, df_train.columns != 'Exited'])
log_pol2 = LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,intercept_scaling=1, max_iter=300, multi_class='auto', n_jobs=None,
                              penalty='l2', random_state=None, solver='liblinear',tol=0.0001, verbose=0, warm_start=False)
log_pol2.fit(df_train_pol2,df_train.Exited)

# %%
# Fit SVM with RBF Kernel
SVM_RBF = SVC(C=100, cache_size=200, class_weight=None, coef0=0.0, decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf', max_iter=-1, probability=True,
              random_state=None, shrinking=True,tol=0.001, verbose=False)
SVM_RBF.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)
# Out:
# SVC(C=100, gamma=0.1, probability=True)

# %%
# Fit SVM with Pol Kernel
SVM_POL = SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,  decision_function_shape='ovr', degree=2, gamma=0.1, kernel='poly',  max_iter=-1,
              probability=True, random_state=None, shrinking=True, tol=0.001, verbose=False)
SVM_POL.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)

# %%
# Fit Random Forest classifier
RF = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',max_depth=8, max_features=6, max_leaf_nodes=None,min_impurity_decrease=0.0
                            ,min_samples_leaf=1, min_samples_split=3,min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=None,
                            oob_score=False, random_state=None, verbose=0,warm_start=False)
RF.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)

# %%
# Fit Extreme Gradient Boost Classifier
XGB = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,colsample_bytree=1, gamma=0.01, learning_rate=0.1, max_delta_step=0,max_depth=7,
                    min_child_weight=5, missing=None, n_estimators=20,n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,reg_alpha=0,
                    reg_lambda=1, scale_pos_weight=1, seed=None, silent=True, subsample=1)
XGB.fit(df_train.loc[:, df_train.columns != 'Exited'],df_train.Exited)

# %% [markdown]
# ### Review best model fit accuracy : Keen interest is on the performance in predicting 1's (Customers who churn)

# %%
print(classification_report(df_train.Exited, log_primal.predict(df_train.loc[:, df_train.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89      6353
#            1       0.64      0.24      0.35      1647
#
#     accuracy                           0.82      8000
#    macro avg       0.73      0.60      0.62      8000
# weighted avg       0.79      0.82      0.78      8000

# %%
print(classification_report(df_train.Exited,  log_pol2.predict(df_train_pol2)))

# %%
print(classification_report(df_train.Exited,  SVM_RBF.predict(df_train.loc[:, df_train.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6353
#            1       0.85      0.40      0.54      1647
#
#     accuracy                           0.86      8000
#    macro avg       0.86      0.69      0.73      8000
# weighted avg       0.86      0.86      0.84      8000

# %%
print(classification_report(df_train.Exited,  SVM_POL.predict(df_train.loc[:, df_train.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92      6353
#            1       0.84      0.38      0.52      1647
#
#     accuracy                           0.86      8000
#    macro avg       0.85      0.68      0.72      8000
# weighted avg       0.85      0.86      0.83      8000

# %%
print(classification_report(df_train.Exited,  RF.predict(df_train.loc[:, df_train.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      6353
#            1       0.90      0.52      0.65      1647
#
#     accuracy                           0.89      8000
#    macro avg       0.89      0.75      0.79      8000
# weighted avg       0.89      0.89      0.88      8000

# %%
XGB = XGBClassifier(
    # Other parameters...
    missing=np.nan  # Set to np.nan or another numeric value if your dataset has missing values
)

XGB.fit(df_train.loc[:, df_train.columns != 'Exited'], df_train.Exited)

print(classification_report(df_train.Exited,  XGB.predict(df_train.loc[:, df_train.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6353
#            1       0.98      0.88      0.93      1647
#
#     accuracy                           0.97      8000
#    macro avg       0.98      0.94      0.95      8000
# weighted avg       0.97      0.97      0.97      8000

# %%
y = df_train.Exited
X = df_train.loc[:, df_train.columns != 'Exited']
X_pol2 = df_train_pol2
auc_log_primal, fpr_log_primal, tpr_log_primal = get_auc_scores(y, log_primal.predict(X),log_primal.predict_proba(X)[:,1])
auc_log_pol2, fpr_log_pol2, tpr_log_pol2 = get_auc_scores(y, log_pol2.predict(X_pol2),log_pol2.predict_proba(X_pol2)[:,1])
auc_SVM_RBF, fpr_SVM_RBF, tpr_SVM_RBF = get_auc_scores(y, SVM_RBF.predict(X),SVM_RBF.predict_proba(X)[:,1])
auc_SVM_POL, fpr_SVM_POL, tpr_SVM_POL = get_auc_scores(y, SVM_POL.predict(X),SVM_POL.predict_proba(X)[:,1])
auc_RF, fpr_RF, tpr_RF = get_auc_scores(y, RF.predict(X),RF.predict_proba(X)[:,1])
auc_XGB, fpr_XGB, tpr_XGB = get_auc_scores(y, XGB.predict(X),XGB.predict_proba(X)[:,1])

# %%
plt.figure(figsize = (12,6), linewidth= 1)
plt.plot(fpr_log_primal, tpr_log_primal, label = 'log primal Score: ' + str(round(auc_log_primal, 5)))
plt.plot(fpr_log_pol2, tpr_log_pol2, label = 'log pol2 score: ' + str(round(auc_log_pol2, 5)))
plt.plot(fpr_SVM_RBF, tpr_SVM_RBF, label = 'SVM RBF Score: ' + str(round(auc_SVM_RBF, 5)))
plt.plot(fpr_SVM_POL, tpr_SVM_POL, label = 'SVM POL Score: ' + str(round(auc_SVM_POL, 5)))
plt.plot(fpr_RF, tpr_RF, label = 'RF score: ' + str(round(auc_RF, 5)))
plt.plot(fpr_XGB, tpr_XGB, label = 'XGB score: ' + str(round(auc_XGB, 5)))
plt.plot([0,1], [0,1], 'k--', label = 'Random: 0.5')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve')
plt.legend(loc='best')
#plt.savefig('roc_results_ratios.png')
plt.show()

# %% [markdown]
# The ROC curve displayed in the image compares the performance of several classification models used for a binary classification task. Each line represents a different model, and the AUC (Area Under the Curve) score for each model is provided in the legend.
#
# Here's a breakdown of the ROC curve and what it tells us about each model:
#
# - **XGB (Extreme Gradient Boosting)**: The brown line with an AUC score of 0.93625 is the highest among all the models. It is closest to the top-left corner, indicating excellent performance in distinguishing between the positive and negative classes.
#
# - **RF (Random Forest)**: The green line with an AUC score of 0.75077 is below the XGB curve but still shows good performance. It is not as close to the top-left corner as the XGB model, which means it's less effective at distinguishing between the classes compared to XGB.
#
# - **SVM POL (Support Vector Machine with Polynomial Kernel)**: The red line with an AUC score of 0.67916 is below the RF curve, indicating moderate performance. It's better than random guessing but not as good as the RF or XGB models.
#
# - **SVM RBF (Support Vector Machine with Radial Basis Function Kernel)**: The orange line with an AUC score of 0.69063 is similar to the SVM POL model in terms of AUC, suggesting similar performance in class discrimination.
#
# - **log pol2 (Logistic Regression with Polynomial Features)**: The light blue line with an AUC score of 0.71068 performs better than both SVM models but is not as effective as the RF model.
#
# - **log primal (Logistic Regression)**: The dark blue line with an AUC score of 0.601 is the lowest among the machine learning models and is only slightly better than random guessing. This indicates that the logistic regression model without polynomial features is the least effective at distinguishing between the classes.
#
# - **Random**: The black dashed line represents a completely random classifier with an AUC score of 0.5. Any model that performs better than this line is considered to have some ability to distinguish between the classes.
#
# In summary, the XGB model is the best performer, with the highest AUC score, indicating it has the best capability to distinguish between the positive and negative classes. The other models show varying degrees of effectiveness, with the logistic regression model without polynomial features being the least effective among those presented.

# %% [markdown]
# ## Step 6. Solution and Justification
#
#
# ### Pseudocode
#
# 1. Load Data
#    - Read the CSV file containing customer data.
#
# 2. Data Preprocessing
#    - Handle missing values by imputation or exclusion.
#    - Normalize continuous variables like Age, Tenure, Balance, and EstimatedSalary.
#    - Encode categorical variables (Geography, Gender) using one-hot encoding.
#
# 3. Feature Engineering
#    - Create new feature "BalanceToSalaryRatio" as Balance / EstimatedSalary.
#    - Create new feature "AgeGroup" by categorizing Age into groups (e.g., 18-25, 26-35, etc.).
#
# 4. Handle Imbalanced Dataset
#    - If dataset is imbalanced, apply SMOTE or undersampling to balance the classes.
#
# 5. Split Data
#    - Split the dataset into training and testing sets (e.g., 80% training, 20% testing).
#
# 6. Model Selection and Training
#    - Train multiple models (e.g., Logistic Regression, Random Forest, Gradient Boosting) on the training set.
#    - Use cross-validation to fine-tune model parameters and prevent overfitting.
#
# 7. Model Evaluation
#    - Evaluate each model on the testing set using metrics like accuracy, precision, recall, and F1-score.
#    - Select the model with the best balance of performance metrics.
#
# 8. Interpret Model
#    - Use techniques like feature importance to understand the top features influencing churn predictions.
#
# 9. Predict Churn
#    - Use the selected model to predict churn probabilities on the testing set.
#
# 10. Output Results
#     - Write the CustomerID and predicted ChurnProbability to a CSV file.
#
# ### Solution
#
# **The XGBoost is the best performer, with the highest accuracy, precision, recall, and f1-score, making it the most suitable choice for accurately predicting Class 1 instances (e.g., churned customers) in this context. Its high precision and recall indicate it can correctly identify a high percentage of actual Class 1 instances while minimizing the number of false positives and negatives. This model would be the most effective for implementing targeted retention strategies, as it accurately identifies the customers most at risk of churning.**
#
# **From the above results, my main aim is to predict the customers that will possibly churn so they can be put in some sort of scheme to prevent churn hence the recall measures on the 1's is of more importance to me than the overall accuracy score of the model.**
#
# **Given that in the data we only had 20% of churn, a recall greater than this baseline will already be an improvement but we want to get as high as possible while trying to maintain a high precision so that the bank can train its resources effectively towards clients highlighted by the model without wasting too much resources on the false positives.**
#
# **From the review of the fitted models above, the best model that gives a decent balance of the recall and precision is the random forest where according to the fit on the training set, with a precision score on 1's of 0.88, out of all customers that the model thinks will churn, 88% do actually churn and with the recall score of 0.53 on the 1's, the model is able to highlight 53% of all those who churned.**

# %% [markdown]
# ### Test model prediction accuracy on test data

# %%
# Make the data transformation for test data
df_test = DfPrepPipeline(df_test,df_train.columns,minVec,maxVec)
df_test = df_test.mask(np.isinf(df_test))
df_test = df_test.dropna()
df_test.shape
# Out:
# <ipython-input-28-1a8af6dd60d1>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict[i+'_'+j] = np.where(df_predict[i] == j,1,-1)
# <ipython-input-28-1a8af6dd60d1>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_predict[i+'_'+j] = np.where(df_predict[i] == j,1,-1)
# <ipython-input-28-1a8af6dd60d1>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
print(classification_report(df_test.Exited,  RF.predict(df_test.loc[:, df_test.columns != 'Exited'])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1607
#            1       0.80      0.42      0.55       389
#
#     accuracy                           0.87      1996
#    macro avg       0.84      0.70      0.73      1996
# weighted avg       0.86      0.87      0.85      1996

# %%
auc_RF_test, fpr_RF_test, tpr_RF_test = get_auc_scores(df_test.Exited, RF.predict(df_test.loc[:, df_test.columns != 'Exited']),
                                                       RF.predict_proba(df_test.loc[:, df_test.columns != 'Exited'])[:,1])
plt.figure(figsize = (12,6), linewidth= 1)
plt.plot(fpr_RF_test, tpr_RF_test, label = 'RF score: ' + str(round(auc_RF_test, 5)))
plt.plot([0,1], [0,1], 'k--', label = 'Random: 0.5')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve')
plt.legend(loc='best')
#plt.savefig('roc_results_ratios.png')
plt.show()

# %% [markdown]
# This ROC curve illustrates the performance of a Random Forest (RF) classifier for a binary classification task. The curve plots the True Positive Rate (TPR) against the False Positive Rate (FPR) at various threshold settings.
#
# Here's a detailed explanation of the curve:
#
# - **RF Score**: The blue line represents the performance of the Random Forest classifier. The AUC score for this model is approximately 0.68293, as indicated in the legend. This score is a measure of the model's ability to discriminate between the positive and negative classes. An AUC score of 0.68293 means the model has a fair discrimination capacity, which is better than random guessing but not excellent.
#
# - **Curve Shape**: The curve starts at the bottom left corner (0,0) and ends at the top right corner (1,1). Ideally, a perfect classifier would have a curve that goes straight up the y-axis and then along the x-axis, indicating a high TPR and a low FPR across all thresholds. The RF curve here is above the diagonal line but not close to the 'ideal' curve, suggesting that the model correctly identifies a good number of positive instances but also misclassifies a certain amount of negative instances as positive.
#
# - **Random**: The black dashed line represents the ROC curve of a random classifier (AUC = 0.5). Any practical classifier should perform better than this line, and the RF model does so, as its curve is above the dashed line.
#
# - **Interpretation**: The RF model's ROC curve shows that as the threshold for classifying a positive instance is lowered, both the TPR and FPR increase. However, the TPR increases at a faster rate than the FPR until a certain point, after which the gains in TPR become smaller relative to the increase in FPR. This indicates that there is a range of thresholds where the model has a relatively better balance between sensitivity and specificity.
#
# In summary, the ROC curve for the RF classifier indicates that the model has a fair ability to distinguish between the two classes, with an AUC score that is significantly better than random chance but not close to perfect. The model may benefit from further tuning or the use of more sophisticated algorithms to improve its discriminative power.

# %% [markdown]
# ##  7. With code and results above of the problem we have have concluded:

# %% [markdown]
# Based on the results and code snippets provided, along with the ROC curves, we can draw the following detailed conclusions:
#
# 1. **Model Performance**:
#
#    - The **XGBoost** model outperforms all other models with an AUC score of 0.93625, indicating a strong ability to discriminate between the positive (e.g., churned customers) and negative classes.
#
#    - The **Random Forest** model has a fair performance with an AUC of 0.75077, which is significantly better than random chance but not as high as XGBoost.
#
#    - **SVM with Polynomial Kernel** and **SVM with RBF Kernel** have moderate AUC scores of 0.67916 and 0.69063, respectively, suggesting they are less effective than XGBoost and Random Forest in this task.
#
#    - **Logistic Regression** models, both with and without polynomial features, have the lowest AUC scores, indicating they are the least effective among the tested models for this particular problem.
#
#
# 2. **ROC Curve Analysis**:
#
#    - The ROC curves provide a visual comparison of model performance. The closer a curve is to the top-left corner of the plot, the better the model is at distinguishing between classes.
#
#    - The **XGBoost** curve is nearest to the top-left corner, which visually confirms its superior performance.
#
#    - The **Random Forest** curve, while above the diagonal line of randomness, is not as steep as the XGBoost curve, which visually confirms its lower but still reasonable performance.
#
#    - The curves for the **SVM** models and **Logistic Regression** are closer to the diagonal line, indicating less discriminative power.
#
# 3. **Classification Report Analysis**:
#
#    - The classification reports provide detailed metrics such as precision, recall, and f1-score for each class. These metrics are crucial for understanding how well the models perform, especially in the context of imbalanced classes.
#
#    - The best model, according to the classification reports, is the one with the highest f1-score for the minority class (Class 1), which is typically the class of interest in churn prediction. This is because f1-score balances the precision and recall, providing a single metric for model performance on the minority class.
#
# 4. **Practical Implications**:
#
#    - The **XGBoost** model, with its high precision and recall for the minority class, would be the most suitable for identifying customers at risk of churn. This allows for targeted interventions to retain valuable customers.
#
#    - The **Random Forest** model, with its reasonable performance, could be a good secondary choice, especially if model interpretability is a concern, as Random Forest can provide insights into feature importance.
#
# 5. **Recommendations for Improvement**:
#
#    - Further tuning of hyperparameters might improve the performance of the models, especially those with lower AUC scores.
#
#    - Additional feature engineering could be explored to provide the models with more discriminative information.
#
#    - Ensemble methods or stacking could be used to combine the predictions of multiple models to improve overall performance.
#
# 6. **Ethical and Business Considerations**:
#
#    - The models should be regularly updated with new data to ensure their predictions remain relevant and accurate over time.
#
#    - It is important to consider the ethical implications of the models' predictions, ensuring that they do not discriminate against any group of customers.
#
#
# In conclusion, the analysis of the models' performance through ROC curves and classification reports suggests that the XGBoost model is the most effective for this binary classification task. However, it is important to consider both the quantitative metrics and the qualitative aspects such as model interpretability, ethical considerations, and business needs when choosing the final model for deployment.
